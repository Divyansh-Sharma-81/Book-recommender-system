# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv')
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')
# Out:
# /tmp/ipykernel_24847/1748781244.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %% [markdown]
# ## Checking dataframes' shapes

# %%
books.shape
# Out:
# (271360, 8)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
users.shape
# Out:
# (278858, 3)

# %% [markdown]
# ## Checking number of nulls

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# ## Checking number of duplicates

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings.merge(books,on='ISBN')
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
# now we want each book's avg rating and only consider books with no. of ratings > 200

# %%
ratings_with_name.groupby('Book-Title').count()
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        4     4
#  Always Have Popsicles                                    1     1
#  Apple Magic (The Collector's series)                     1     1
#  Ask Lily (Young Women of Faith: Lily Series, B...        1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
# ...                                                     ...   ...
# Ã?Â?lpiraten.                                             2     2
# Ã?Â?rger mit Produkt X. Roman.                            4     4
# Ã?Â?sterlich leben.                                       1     1
# Ã?Â?stlich der Berge.                                     3     3
# Ã?Â?thique en toc                                         2     2
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %%
ratings_with_name.groupby('Book-Title').count()['Book-Rating']
# Out:
# Book-Title
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    4
#  Always Have Popsicles                                                                                        1
#  Apple Magic (The Collector's series)                                                                         1
#  Ask Lily (Young Women of Faith: Lily Series, Book 5)                                                         1
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   1
#                                                                                                              ..
# Ã?Â?lpiraten.                                                                                                 2
# Ã?Â?rger mit Produkt X. Roman.                                                                                4
# ...

# %%
# we got a series with the book names as the index and num of ratings as value

# %%
ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
# storing in a variable and using convenient names

# %%
num_ratings_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_ratings_df.rename(columns={'Book-Rating':'num_ratings'}, inplace=True)

# %%
num_ratings_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
# now to get avg ratings lets make new df to store book nname and corresponding avg rating

# %%
# replace count with mean
# ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()

# %%
# debugging the error

# %%
print(ratings_with_name.dtypes)
# Out:
# User-ID                 int64
# ISBN                   object
# Book-Rating             int64
# Book-Title             object
# Book-Author            object
# Year-Of-Publication    object
# Publisher              object
# Image-URL-S            object
# Image-URL-M            object
# Image-URL-L            object
# dtype: object

# %%
# book rating is not numeric

# %%
ratings_with_name['Book-Rating'] = pd.to_numeric(ratings_with_name['Book-Rating'], errors='coerce')

# %%
ratings_with_name = ratings_with_name.dropna(subset=['Book-Rating'])

# %%
avg_ratings = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
print(avg_ratings)
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
avg_ratings.rename(columns={'Book-Rating':'avg_ratings'}, inplace=True)

# %%
avg_ratings
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
# merging num and avg df
popularity_df = num_ratings_df.merge(avg_ratings,on='Book-Title')

# %%
popularity_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
# we only want to keep books with num ratings>150

# %%
popularity_df['num_ratings']>=150
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 241066    False
# 241067    False
# 241068    False
# 241069    False
# 241070    False
# Name: num_ratings, Length: 241071, dtype: bool

# %%
# putting the boolean series into popularity_df to filter out the rows

# %%
popularity_df[popularity_df['num_ratings']>=150].sort_values('avg_ratings',ascending=False)
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 60582       Ender's Game (Ender Wiggins Saga (Paperback))          249
# ...                                                   ...          ...
# 163913  Songs in Ordinary Time (Oprah's Book Club (Pap...          232
# 180094     The Cardinal of the Kremlin (Jack Ryan Novels)          166
# 143571                Primary Colors: A Novel of Politics          166
# 179597                                The Burden of Proof          153
# 234951                                        Wild Animus         2502
#
#         avg_ratings
# 80434      5.852804
# 80422      5.824289
# 80441      5.737410
# 80426      5.501441
# ...

# %%
popularity_df = popularity_df[popularity_df['num_ratings']>=150].sort_values('avg_ratings',ascending=False)

# %%
# now that we have this dataframe ready lets go on to get author name, book image and other details relevant(maybe publisher detail?)

# %%
popularity_df.merge(books, on='Book-Title')
# Out:
#                                              Book-Title  num_ratings  \
# 0     Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 1     Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 2     Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3          Harry Potter and the Goblet of Fire (Book 4)          387
# 4          Harry Potter and the Goblet of Fire (Book 4)          387
# ...                                                 ...          ...
# 1758                Primary Colors: A Novel of Politics          166
# 1759                Primary Colors: A Novel of Politics          166
# 1760                                The Burden of Proof          153
# 1761                                The Burden of Proof          153
# 1762                                        Wild Animus         2502
#
#       avg_ratings        ISBN    Book-Author Year-Of-Publication  \
# 0        5.852804  0439136350  J. K. Rowling                1999
# ...

# %%
# as we can see, same book title has multiple isbn numbers, so lets clear them out

# %%
popularity_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')
# Out:
#                                              Book-Title  num_ratings  \
# 0     Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3          Harry Potter and the Goblet of Fire (Book 4)          387
# 5        Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9     Harry Potter and the Order of the Phoenix (Boo...          347
# 13        Ender's Game (Ender Wiggins Saga (Paperback))          249
# ...                                                 ...          ...
# 1756  Songs in Ordinary Time (Oprah's Book Club (Pap...          232
# 1757     The Cardinal of the Kremlin (Jack Ryan Novels)          166
# 1758                Primary Colors: A Novel of Politics          166
# 1760                                The Burden of Proof          153
# 1762                                        Wild Animus         2502
#
#       avg_ratings        ISBN          Book-Author Year-Of-Publication  \
# ...

# %%
# fileting useful columns

# %%
popularity_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_ratings']]
# Out:
#                                              Book-Title          Book-Author  \
# 0     Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 3          Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# 5        Harry Potter and the Sorcerer's Stone (Book 1)        J. K. Rowling
# 9     Harry Potter and the Order of the Phoenix (Boo...        J. K. Rowling
# 13        Ender's Game (Ender Wiggins Saga (Paperback))     Orson Scott Card
# ...                                                 ...                  ...
# 1756  Songs in Ordinary Time (Oprah's Book Club (Pap...  Mary McGarry Morris
# 1757     The Cardinal of the Kremlin (Jack Ryan Novels)           Tom Clancy
# 1758                Primary Colors: A Novel of Politics            Anonymous
# 1760                                The Burden of Proof          Scott Turow
# 1762                                        Wild Animus         Rich Shapero
#
# ...

# %%
popularity_df = popularity_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_ratings']]

# %%
# now data is prepared

# %% [markdown]
# ## collaboraive filtering data prep

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
ratings_with_name.groupby('User-ID').count()['Book-Rating']
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
#finding experienced users

# %%
ratings_with_name.groupby('User-ID').count()
# Out:
#          ISBN  Book-Rating  Book-Title  Book-Author  Year-Of-Publication  \
# User-ID
# 2           1            1           1            1                    1
# 8          17           17          17           17                   17
# 9           3            3           3            3                    3
# 10          1            1           1            1                    1
# 12          1            1           1            1                    1
# ...       ...          ...         ...          ...                  ...
# 278846      1            1           1            1                    1
# 278849      4            4           4            4                    4
# 278851     23           23          23           23                   23
# 278852      1            1           1            1                    1
# 278854      8            8           8            8                    8
#
#          Publisher  Image-URL-S  Image-URL-M  Image-URL-L
# User-ID
# ...

# %%
ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
# Out:
# User-ID
# 2         False
# 8         False
# 9         False
# 10        False
# 12        False
#           ...
# 278846    False
# 278849    False
# 278851    False
# 278852    False
# 278854    False
# Name: Book-Rating, Length: 92106, dtype: bool

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
x[x]
# Out:
# User-ID
# 254       True
# 2276      True
# 2766      True
# 2977      True
# 3363      True
#           ...
# 274308    True
# 275970    True
# 277427    True
# 277639    True
# 278418    True
# Name: Book-Rating, Length: 811, dtype: bool

# %%
# fetching all required user ids
educ_users = x[x].index

# %%
ratings_with_name['User-ID'].isin(educ_users)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1031131    False
# 1031132    False
# 1031133    False
# 1031134    False
# 1031135    False
# Name: User-ID, Length: 1031136, dtype: bool

# %%
ratings_with_name[ratings_with_name['User-ID'].isin(educ_users)]
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
filtered_ratings = ratings_with_name[ratings_with_name['User-ID'].isin(educ_users)]

# %%
filtered_ratings.groupby('Book-Title').count()
# Out:
#                                                     User-ID  ISBN  \
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...        2     2
#  Always Have Popsicles                                    1     1
#  Apple Magic (The Collector's series)                     1     1
#  Beyond IBM: Leadership Marketing and Finance f...        1     1
#  Clifford Visita El Hospital (Clifford El Gran ...        1     1
# ...                                                     ...   ...
# Ã?Â?ber das Fernsehen.                                    2     2
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den St...        3     3
# Ã?Â?lpiraten.                                             1     1
# Ã?Â?stlich der Berge.                                     1     1
# Ã?Â?thique en toc                                         1     1
#
#                                                     Book-Rating  Book-Author  \
# Book-Title
# ...

# %%
y = filtered_ratings.groupby('Book-Title').count()['Book-Rating']>=50
y[y]
# Out:
# Book-Title
# 1984                                                                 True
# 1st to Die: A Novel                                                  True
# 2nd Chance                                                           True
# 4 Blondes                                                            True
# A Bend in the Road                                                   True
#                                                                      ...
# Year of Wonders                                                      True
# You Belong To Me                                                     True
# Zen and the Art of Motorcycle Maintenance: An Inquiry into Values    True
# Zoya                                                                 True
# \O\" Is for Outlaw"                                                  True
# Name: Book-Rating, Length: 706, dtype: bool

# %%
famous_books = y[y].index

# %%
filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
final_ratings = filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]

# %%
filtered_ratings['Image-URL-M']
# Out:
# 1150       http://images.amazon.com/images/P/002542730X.0...
# 1151       http://images.amazon.com/images/P/0026217457.0...
# 1152       http://images.amazon.com/images/P/003008685X.0...
# 1153       http://images.amazon.com/images/P/0030615321.0...
# 1154       http://images.amazon.com/images/P/0060002050.0...
#                                  ...
# 1029357    http://images.amazon.com/images/P/1931868123.0...
# 1029358    http://images.amazon.com/images/P/3411086211.0...
# 1029359    http://images.amazon.com/images/P/3829021860.0...
# 1029360    http://images.amazon.com/images/P/4770019572.0...
# 1029361    http://images.amazon.com/images/P/9626340762.0...
# Name: Image-URL-M, Length: 474007, dtype: object

# %%
final_ratings.pivot_table(index = 'Book-Title',columns='User-ID', values = 'Book-Rating')
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt = final_ratings.pivot_table(index = 'Book-Title',columns='User-ID', values = 'Book-Rating')

# %%
pt.fillna(0, inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(pt) , cosine_similarity(pt).shape
# Out:
# (array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#          0.04316046],
#         [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#          0.14263397],
#         [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#          0.10796119],
#         ...,
#         [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#          0.0196177 ],
#         [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#          0.10602962],
#         [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#          1.        ]]),
#  (706, 706))

# %%
#hence similarity value of all 706 books wrt all 706 books is shown in a matrix as above

# %%
sim_matrix = cosine_similarity(pt)

# %%
def recommend(book_name,num_books=8):
    #index fetching for particular book
    index = np.where(pt.index==book_name)[0][0]

    # finding the similarity scores of the given book with all others
    distances = sim_matrix[index]
    num_books = num_books+1
    sim_items = sorted(list(enumerate(distances)), key= lambda x:x[1],reverse=True)[1:num_books]


    data = []
    
    for i in sim_items:
        item=[]
        temp_df = books[books['Book-Title']==pt.index[i[0]]]
        # print(temp_df.drop_duplicates('Book-Title')['Book-Author']) #as an example
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)

    return data
    # return suggestions

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ['The Hours : A Novel',
#   'Michael Cunningham',
#   'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg'],
#  ['Fahrenheit 451',
#   'Ray Bradbury',
#   'http://images.amazon.com/images/P/3257208626.01.MZZZZZZZ.jpg'],
#  ['The Catcher in the Rye',
#   'J.D. Salinger',
#   'http://images.amazon.com/images/P/0316769487.01.MZZZZZZZ.jpg'],
#  ['Naked',
#   'David Sedaris',
#   'http://images.amazon.com/images/P/0316777730.01.MZZZZZZZ.jpg']]

# %%
####################################################

# %%
# explanation of parts of above fn

# %%
np.where(pt.index=='4 Blondes')[0][0]
# Out:
# 3

# %%
a1 = np.where(pt.index=='4 Blondes')[0][0]

# %%
sim_matrix[a1]
# Out:
# array([0.        , 0.        , 0.        , 1.        , 0.        ,
#        0.11158235, 0.        , 0.        , 0.07439555, 0.        ,
#        0.        , 0.14576203, 0.05499338, 0.        , 0.        ,
#        0.        , 0.        , 0.04289816, 0.        , 0.11215379,
#        0.        , 0.        , 0.02473898, 0.        , 0.0254068 ,
#        0.12305174, 0.        , 0.        , 0.        , 0.        ,
#        0.09381049, 0.        , 0.06859607, 0.        , 0.0779401 ,
#        0.03771542, 0.08134518, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.05477141, 0.        , 0.05958855,
#        0.        , 0.        , 0.07684047, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.06703391,
#        0.        , 0.        , 0.03245271, 0.        , 0.0408861 ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.0094036 , 0.        , 0.        , 0.00939554, 0.        ,
# ...

# %%
a2 = sim_matrix[a1]

# %%
enumerate(a2)

# %%
list(enumerate(a2))
# Out:
# [(0, 0.0),
#  (1, 0.0),
#  (2, 0.0),
#  (3, 1.0),
#  (4, 0.0),
#  (5, 0.11158234783062482),
#  (6, 0.0),
#  (7, 0.0),
#  (8, 0.07439555056493442),
#  (9, 0.0),
#  (10, 0.0),
#  (11, 0.14576203341012606),
#  (12, 0.05499338389911775),
#  (13, 0.0),
#  (14, 0.0),
#  (15, 0.0),
#  (16, 0.0),
#  (17, 0.042898160366533294),
#  (18, 0.0),
#  (19, 0.11215378957501862),
#  (20, 0.0),
#  (21, 0.0),
#  (22, 0.024738980596645314),
#  (23, 0.0),
#  (24, 0.02540679568643376),
#  (25, 0.12305173578602326),
#  (26, 0.0),
#  (27, 0.0),
#  (28, 0.0),
#  (29, 0.0),
#  (30, 0.093810493917375),
#  (31, 0.0),
#  (32, 0.06859607433155815),
#  (33, 0.0),
#  (34, 0.07794009648081775),
#  (35, 0.03771541627007571),
#  (36, 0.08134518347820842),
#  (37, 0.0),
#  (38, 0.0),
#  (39, 0.0),
#  (40, 0.0),
#  (41, 0.0),
#  (42, 0.05477141171610637),
#  (43, 0.0),
#  (44, 0.05958854548495317),
#  (45, 0.0),
#  (46, 0.0),
#  (47, 0.076840468344349),
#  (48, 0.0),
#  (49, 0.0),
#  (50, 0.0),
#  (51, 0.0),
# ...

# %%
# now sort

# %%
sorted(list(enumerate(a2))) # by default it sorts by 1st value, so need to change
# Out:
# [(0, 0.0),
#  (1, 0.0),
#  (2, 0.0),
#  (3, 1.0),
#  (4, 0.0),
#  (5, 0.11158234783062482),
#  (6, 0.0),
#  (7, 0.0),
#  (8, 0.07439555056493442),
#  (9, 0.0),
#  (10, 0.0),
#  (11, 0.14576203341012606),
#  (12, 0.05499338389911775),
#  (13, 0.0),
#  (14, 0.0),
#  (15, 0.0),
#  (16, 0.0),
#  (17, 0.042898160366533294),
#  (18, 0.0),
#  (19, 0.11215378957501862),
#  (20, 0.0),
#  (21, 0.0),
#  (22, 0.024738980596645314),
#  (23, 0.0),
#  (24, 0.02540679568643376),
#  (25, 0.12305173578602326),
#  (26, 0.0),
#  (27, 0.0),
#  (28, 0.0),
#  (29, 0.0),
#  (30, 0.093810493917375),
#  (31, 0.0),
#  (32, 0.06859607433155815),
#  (33, 0.0),
#  (34, 0.07794009648081775),
#  (35, 0.03771541627007571),
#  (36, 0.08134518347820842),
#  (37, 0.0),
#  (38, 0.0),
#  (39, 0.0),
#  (40, 0.0),
#  (41, 0.0),
#  (42, 0.05477141171610637),
#  (43, 0.0),
#  (44, 0.05958854548495317),
#  (45, 0.0),
#  (46, 0.0),
#  (47, 0.076840468344349),
#  (48, 0.0),
#  (49, 0.0),
#  (50, 0.0),
#  (51, 0.0),
# ...

# %%
sorted(list(enumerate(a2)), key= lambda x:x[1])
# Out:
# [(0, 0.0),
#  (1, 0.0),
#  (2, 0.0),
#  (4, 0.0),
#  (6, 0.0),
#  (7, 0.0),
#  (9, 0.0),
#  (10, 0.0),
#  (13, 0.0),
#  (14, 0.0),
#  (15, 0.0),
#  (16, 0.0),
#  (18, 0.0),
#  (20, 0.0),
#  (21, 0.0),
#  (23, 0.0),
#  (26, 0.0),
#  (27, 0.0),
#  (28, 0.0),
#  (29, 0.0),
#  (31, 0.0),
#  (33, 0.0),
#  (37, 0.0),
#  (38, 0.0),
#  (39, 0.0),
#  (40, 0.0),
#  (41, 0.0),
#  (43, 0.0),
#  (45, 0.0),
#  (46, 0.0),
#  (48, 0.0),
#  (49, 0.0),
#  (50, 0.0),
#  (51, 0.0),
#  (52, 0.0),
#  (53, 0.0),
#  (55, 0.0),
#  (56, 0.0),
#  (58, 0.0),
#  (60, 0.0),
#  (61, 0.0),
#  (62, 0.0),
#  (63, 0.0),
#  (64, 0.0),
#  (66, 0.0),
#  (67, 0.0),
#  (69, 0.0),
#  (70, 0.0),
#  (71, 0.0),
#  (72, 0.0),
#  (74, 0.0),
#  (75, 0.0),
#  (76, 0.0),
#  (77, 0.0),
#  (78, 0.0),
#  (79, 0.0),
#  (81, 0.0),
#  (83, 0.0),
#  (84, 0.0),
#  (85, 0.0),
#  (86, 0.0),
#  (89, 0.0),
#  (90, 0.0),
#  (91, 0.0),
#  (92, 0.0),
#  (93, 0.0),
#  (94, 0.0),
#  (95, 0.0),
#  (96, 0.0),
#  (97, 0.0),
#  (98, 0.0),
# ...

# %%
# but most similar are at bottom, hence reversing needed
sorted(list(enumerate(a2)), key= lambda x:x[1],reverse=True)
# Out:
# [(3, 1.0),
#  (553, 0.21653836784507968),
#  (389, 0.19281549158555333),
#  (378, 0.18082023336625944),
#  (420, 0.17982397105535214),
#  (358, 0.1717379494369234),
#  (88, 0.17154710645770874),
#  (417, 0.16338132022337623),
#  (576, 0.15044464825156875),
#  (241, 0.14887459750526022),
#  (521, 0.14774674418855002),
#  (11, 0.14576203341012606),
#  (157, 0.14343388988137237),
#  (322, 0.14284952400575568),
#  (499, 0.13903237199542137),
#  (494, 0.13638740566268653),
#  (384, 0.13583222341573237),
#  (397, 0.13520967471697068),
#  (360, 0.13237923547629468),
#  (511, 0.13186636439267943),
#  (87, 0.1313547114095477),
#  (390, 0.12950201134373315),
#  (197, 0.12883477701962698),
#  (539, 0.1272664459112394),
#  (536, 0.1270720066157662),
#  (691, 0.12634132998528463),
#  (700, 0.1234860763967322),
#  (150, 0.12334015538988931),
#  (25, 0.12305173578602326),
#  (673, 0.1226514425013737),
#  (607, 0.12173922436578168),
#  (442, 0.12113803933659045),
#  (496, 0.12060139688643617),
# ...

# %%
####################################################

# %%
# !pip install flask

# %%
import pickle
pickle.dump(popularity_df, open('popular.pkl', 'wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(sim_matrix,open('sim_matrix.pkl','wb'))
